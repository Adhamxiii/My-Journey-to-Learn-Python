# %% [markdown]
# # Introduction to Data Visualization with Seaborn

# %% [markdown]
# Seaborn is a powerful Python library that makes it easy to create informative and engaging visualizations.

# %% [markdown]
# # 1.Introduction to Seaborn
# Graphic of a typical data analysis workflow

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
height = [62, 64, 69, 75, 66, 68, 65, 71, 76, 73]
weight = [120, 136, 148, 175, 137,165, 154, 172, 200, 187]
sns.scatterplot(x=height, y=weight)
plt.show()

# %%
gender = ["Female", "Female", "Female", "Female", "Male", "Male", "Male", "Male", "Male", "Male"]
sns.countplot(x=gender)
plt.show()

# %% [markdown]
# ## Using pandas with Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/Pokemon.csv")
sns.countplot(x="Total", data=df)
plt.show()

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='smoker', style='smoker', hue_order=['Yes', 'No'])
plt.show()

# %%
hue_colors = {'Yes': '#ff7777', 'No': '#F9FA9B'}
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='smoker', palette=hue_colors)
plt.show()

# %%
sns.countplot(x='smoker', data=tips, hue='sex')
plt.show()

# %% [markdown]
# # 2.Visualizing Two Quantitative Variables
# Introduction to relational plots and subplots

# %%
# relplot() --> Relational plot; create subplots in a single figure

sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', row='time', col='smoker')
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(
    x="total_bill",
    y="tip",
    data=tips,
    kind="scatter",
    col="day",
    col_wrap=2,
    col_order=["Thur", "Fri", "Sat", "Sun"],
)
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Customizing scatter plots

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, size='size', alpha=0.4)
plt.show()

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, size='size', hue='size')
plt.show()

# %% [markdown]
# ## Introduction to line plots

# %%
mpg = sns.load_dataset("mpg")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.relplot(x='model_year', y='mpg', data=mpg, kind='scatter')
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="model_year", y="mpg", data=mpg, kind="line")
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="model_year", y="mpg", data=mpg, kind="line",ci="sd")
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(
    x="model_year",
    y="horsepower",
    data=mpg,
    kind="line",
    ci=None,
    style="origin",
    hue="origin",
    markers=True,
    dashes=False,
)
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # 3. Visualizing a Categorical and a Quantitative Variable
# Count plots and bar plots

# %%
category_order = ["Sun", "Saturday", "Fri", "Thur"]
sns.catplot(x="day", data=tips, kind="count", order=category_order)
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="bar")
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(y="day", x="total_bill", data=tips, kind="bar")

plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(y="day", x="total_bill", data=tips, kind="bar", col="smoker")

plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Box plots

# %%
sns.catplot(x="time", y="total_bill", data=tips, kind="box", order=["Dinner", "Lunch"])
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(
    x="time",
    y="total_bill",
    data=tips,
    kind="box",
    order=["Dinner", "Lunch"],
    whis=[0, 99],
)
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Pont plots

# %%
sns.catplot(x="day", y="total_bill", data=tips, hue="smoker", kind="bar")
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x="day", y="total_bill", data=tips, hue="smoker", kind="point", join=False)
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from numpy import median

sns.catplot(
    x="smoker", y="total_bill", data=tips, kind="point", capsize=0.2, estimator=median
)
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # 4. Customizing Seaborn Plots
# Changing plot style and color

# %%
sns.set_style("whitegrid")
sns.set_palette("RdBu")
sns.set_context("talk")
sns.catplot(
    x="smoker", y="total_bill", data=tips, kind="point", capsize=0.2, estimator=median
)
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Adding titles and labels

# %%
g = sns.catplot(y="day", x="total_bill", data=tips, kind="bar", col="smoker")
g.fig.suptitle("Total Bill by Day and Smoker")
g.set_titles("Smoker: {col_name}")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\theki\AppData\Local\Temp\ipykernel_29580\439114672.py:4: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ## Putting it all together

# %%
survey_data = pd.read_csv("../data/young-people-survey-responses.csv")
survey_data.head(3)
# Out:
#    Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0           0    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1           1    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2           2    5.0     1.0     5.0      1.0          5.0   5.0      1.0
#
#    Loneliness  Parents' advice   Internet usage  Finances   Age  Siblings  \
# 0         3.0              4.0  few hours a day       3.0  20.0       1.0
# 1         2.0              2.0  few hours a day       3.0  19.0       2.0
# 2         5.0              3.0  few hours a day       2.0  20.0       2.0
#
#    Gender Village - town
# 0  female        village
# 1  female           city
# 2  female           city

# %%
sns.set_palette("Blues")

g = sns.catplot(x="Internet usage", y="Age", data=survey_data, kind="box", hue="Gender")

g.fig.suptitle("Age vs Internet usage vs Gender")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\theki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
